# %%
import os
import sys
import shutil
import getpass
import codecs

repos_dir = r'/home/akikun/repos'
sys.path.append(repos_dir)
from sak import display as dp
from rs_corpus import jp

password = 'guoyue21'

# %%
def tts_hikari(text_to_read, wav_path, voice='Hikari', vt_dir=r'/usr/vt'):
    '''
    perform TTS using vtspeech. 
    The output file will be made in {vt_dir}/result/vthenrik/{output_filename}.wav
    
    Args:
        text_to_read (str): text to be read.
        wav_path (path): the output file. 
        voice (str): which voice to be used. default: Hikari.
        vt_dir (path): where vtspeech is installed. default: /usr/vt.
        
    '''
    
    # make tts sample.
    wav_filename = os.path.basename(wav_path).replace('.wav', '')
    command = 'sudo -S ' + os.path.join(vt_dir, 'rest', 'vthenrik') \
    + ' --lang ja' \
    + ' --voice ' + voice \
    + ' --text ' + text_to_read \
    + ' --afile ' + wav_filename

    #password = getpass.getpass()
    #os.system('echo %s | %s' % (password, command))
    # !echo {password} | {command}
    
    # copy the wav file to the desired location.
    wav_path_ = os.path.join(vt_dir, 'result', 'vthenrik', os.path.basename(wav_path))
    shutil.move(wav_path_, wav_path)

# %%
def loop_per_sentence(txt_path, trs_path):
    ''' make a loop per sentences using str and the corresponding trs '''
    
    # read trans.
    with open(trs_path) as f:
        trss = f.read().split('\n')
        trss.remove('')
    len(trss)

    # read text.
    txts = codecs.open(txt_path,"rb",'shift_jisx0213').read().split('\r\n')

    # show script and transcription per sentence.
    trs_ = '' # transcription.
    txt_ = '' # script.
    for i, trs in enumerate(trss):
#         if i > 10:
#             break

        txt = txts[i]
        trs_ += trs
        txt_ += txt
        if '。' in txt:
            yield txt_, trs_
            trs_ = ''
            txt_ = ''

# %%
def check_charactors(txt):
    ng_charactors = ['(', ')', '<', '>', '&']
    check = [1 for i in ng_charactors if i in txt]
    is_ok = True
    if len(check) > 0:
        is_ok = False
    return is_ok

# %%
tts_dir  = r'/home/akikun/Projects/nele/hikari_tts'
# tts_hikari(
#     'まもなく３番線に、列車が参ります。危ないので、白線の内側までお下がりください。', 
#     os.path.join(wav_dir, 'hikari.wav'))
# dp.disp_wav(wav_path)
hikari_dir = r'/home/akikun/Corpus/Japanese/02_USS/Female/04_Hikari'

# %%
# split into sentences.
# for i, txt_ in enumerate(txts.split('。'), start=1):
#     i_str = format(i, '03d')
#     txt = txt_.replace('\r', '').replace('\n', '') + '。'
#     if len(txt) > 1:
#         print('{}:{}'.format(i_str, txt))

# %%
filelist = [file.replace('.txt', '') for file in os.listdir(os.path.join(hikari_dir, 'text')) if len(file) == 14]
filelist.sort()
for filename in filelist[46:]:
    print('\n>>> processing {} ...'.format(filename))
    #filename = 'hikari-001'
    txt_path = os.path.join(hikari_dir, 'text', filename + '.txt')
    trs_path = os.path.join(hikari_dir, 'trans', filename + '.trs')

    i = 0
    error_list = []
    for txt, trs in loop_per_sentence(txt_path, trs_path):
        i += 1
        i_str = format(i, '03d')
        basename = filename + '_' + i_str
        print('=== {} ==='.format(basename))
        print('{}'.format(txt))
        
        if check_charactors(txt):
            tts_hikari(txt, os.path.join(tts_dir, 'wavs', basename + '.wav'))
            with open(os.path.join(tts_dir, 'scripts', basename + '.txt'), 'w') as f:
                f.write(txt)    
            with open(os.path.join(tts_dir, 'scripts', basename + '.trs'), 'w') as f:
                f.write(trs)
        else:
            error_list.append(basename)
            print('+++++ cannot generate audio +++++')
# Out:
# >>> processing hikari-001 ...
# === hikari-001_001 ===
# 米側は「極めて高性能なレーダーを持つ護衛艦」との表現でイージス艦派遣を要請、政府も派遣する方針。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_001.wav
# === hikari-001_002 ===
# 覇者というのはどういう言葉かというと、王者よりワンランク下の称号です。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_002.wav
# === hikari-001_003 ===
# リンクが無料開放され、九千八百人余が訪れた三日のエムウェーブ。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_003.wav
# === hikari-001_004 ===
# 個人の努力や国家のプレッシャーやエリート教育がトップ・アスリートを育てる時代は、もはや終わった。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_004.wav
# === hikari-001_005 ===
# 「モアイ」は、イースター島の石像モアイに由来し「未来を生きる」という意味。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_005.wav
# === hikari-001_006 ===
# 行政や漁業者、住民がより一層連携を強め地域一体となったクリーン運動を続けていきたい。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_006.wav
# === hikari-001_007 ===
# ユニバースは県内をはじめ秋田、岩手県にある全二十二店舗で、雪印食品のハムやソーセージなど十四品目を売り場から撤去。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_007.wav
# === hikari-001_008 ===
# 民主、共和両党のインターネットのホームページは、「有権者登録」を呼びかける。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_008.wav
# === hikari-001_009 ===
# 大リーグのホームランダービーにはすさまじい迫力があり、それがファンを熱狂させるのだ。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_009.wav
# === hikari-001_010 ===
# 研修員はケニア、タンザニア、マラウィ、ウガンダ、ザンビアの大学講師や行政官など農林業専門家ら。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_010.wav
# === hikari-001_011 ===
# 「童謡はだれでも歌えるし、心やすらぐメロディーは島の景色にもよく合うでしょ」。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_011.wav
# === hikari-001_012 ===
# 外部監査の導入も進んでいませんし、ディスクロージャーも不十分。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_012.wav
# === hikari-001_013 ===
# 共通通商政策は関税率の変更、関税・貿易協定の締結、輸出政策、ダンピングや補助金による保護主義的措置への共通原則に基づく。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_013.wav
# === hikari-001_014 ===
# 情報に限らず、あらゆる利益の授受において、強いアミーゴの存在が重要になる。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_014.wav
# === hikari-001_015 ===
# 校長先生にバレーボールとサッカーボールのプレゼントが若い学生の手でおこなわれ、日中友好と平和を誓い合った。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_015.wav
# === hikari-001_016 ===
# スーパー・コンビニ情報網や物流体制整備、「売るものがなくても、明かりはつけておけ」。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_016.wav
# === hikari-001_017 ===
# 自民党は野中幹事長名で連立政権批判や野党候補のパーティーへの出席を禁じる通達を、衆参両院の所属国会議員全員に配布。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_017.wav
# === hikari-001_018 ===
# サービスの内容は、新聞や雑誌の記事、テレビ番組案内など計五チャンネル。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_018.wav
# === hikari-001_019 ===
# えひめ丸移動時は、ロックウオーターを先導し、海流や風などの最新情報を伝える。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_019.wav
# === hikari-001_020 ===
# スーパーマーケットを中心に流通業の成り立ちや規制緩和が招く大競争時代について、上着を脱ぎワイシャツ姿で九十分間話した。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_020.wav
# === hikari-001_021 ===
# 学科ごとに六つのチームに分かれ、約二十五アール分の手植え技術を競った。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_021.wav
# === hikari-001_022 ===
# ハンバーガーや牛どん、衣類などの安売り競争も物価下落に一層の拍車を掛けている。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_022.wav
# === hikari-001_023 ===
# 同社定期バス営業課は「日にちや曜日、季節を限定するバスの新しい運行方法の先がけ」。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_023.wav
# === hikari-001_024 ===
# 手法自体は電話番号アドレスを狙い、数字だけをランダムに発生させた迷惑メールと変わらない。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_024.wav
# === hikari-001_025 ===
# サッカーチーム運営は企業広報の一環という考え方が根強いからだ。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_025.wav
# === hikari-001_026 ===
# アメリカ合衆国は王がいませんから共和制、イギリスは女王がいますね、だから王政。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_026.wav
# === hikari-001_027 ===
# 昨年は、手話で音楽の楽しさを表現する「手話パフォーマンス部門」に出場。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_027.wav
# === hikari-001_028 ===
# その間は皆がタバイと呼ばれる酒を飲んだり踊ったり、水牛レースや腕相撲に興じる。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_028.wav
# === hikari-001_029 ===
# 大型船やタンカーが行き交い、全国のコンテナ輸送の四割を占める東京湾で、パナマ船籍タンカー原油流出事故が起きた。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_029.wav
# === hikari-001_030 ===
# こうべ市民福祉振興協会もホームヘルパー利用者の安否確認を急いだ。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_030.wav
# === hikari-001_031 ===
# 一方、景気の動向については製造業、卸・小売業、サービス業でほぼ半分が「穏やかな後退が続く」と先行きを予想。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_031.wav
# === hikari-001_032 ===
# 生まれた日が少し早いのは、カンガルー科のベネットワラビーの赤ちゃん。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_032.wav
# === hikari-001_033 ===
# 宇宙戦艦ヤマトのテレビ用アニメやビデオ制作を行い、平成五年二月期には年商約十五億円を上げた。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_033.wav
# === hikari-001_034 ===
# 「少年を善い方向へ導くという強い意志を持ってほしい」とエールを送る。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_034.wav
# === hikari-001_035 ===
# ジェイアール四国ホテル開発は現在、全日空エンタープライズと開業までの技術指導契約を結んでいる。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_035.wav
# === hikari-001_036 ===
# アプローチ部分には、間伐材でアーケードを造り、冬には雪のアーケードとなる四季のアーケードを提案した。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_036.wav
# === hikari-001_037 ===
# 区所有の高齢者在宅サービスセンター用地を着工まで地域住民が借り、花や野菜づくりを楽しんだ。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_037.wav
# === hikari-001_038 ===
# ビルの谷間を肌寒い風が吹き抜ける中、踊り手たちは「ヨイヤサー」と元気いっぱい。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_038.wav
# === hikari-001_039 ===
# 看護婦は、まだ生きていた赤ん坊を見せながら、口をガーゼで覆って窒息させたという。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_039.wav
# === hikari-001_040 ===
# 車いす利用者は、運転手が引き出す車両中央ドア下部の収納式スロープ板を使って乗降。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_040.wav
# === hikari-001_041 ===
# 中国は東南アジア諸国連合と自由貿易協定を十年以内に結ぶことを合意している。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_041.wav
# === hikari-001_042 ===
# そうと分かっているのに続いている「野村阪神フィーバー」は何なのか。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_042.wav
# === hikari-001_043 ===
# あらかじめ決定ずみの分野別プロジェクトのうち、最も配分費が多いのは、「通信・空港などのインフラ整備」で九億七千万円。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_043.wav
# === hikari-001_044 ===
# 当時から典型的な「パーティー・ボーイ」で、夜な夜な奇抜な服装でパーティーに出かけては交友関係を広げていったようだ。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_044.wav
# === hikari-001_045 ===
# ディレクターとして、テレビ・ドキュメンタリー作品を数多く制作。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_045.wav
# === hikari-001_046 ===
# 演技を披露するたび、あまりの新奇さに面食らった関係者から「こんなルーチンじゃだめやな」、「幼稚なプログラム」と痛烈な非難を浴びた。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_046.wav
# === hikari-001_047 ===
# 「老いも若きもさあパソコン」と言わんばかりの国の号令が聞こえる。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_047.wav
# === hikari-001_048 ===
# ウォッカは、ロシアの税収の重要な部分を占め、国際競争力をもつ数少ない商品だ。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_048.wav
# === hikari-001_049 ===
# 三月十六日の通り魔事件後の四月初めごろ、少年がリポート用紙に手書きし友人にワープロ打ちさせたらしい。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_049.wav
# === hikari-001_050 ===
# 先月の開場記念イベントで、日本リーグ一部の女子ソフトボールチームを招いたのもワークショップの成果だった。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_050.wav
# === hikari-001_051 ===
# そこでは、ブルドーザーやショベルカーが音をたてて国有林を切り開き、酪農や養豚など畜産農場の造成工事が急ピッチで進んでいた。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_051.wav
# === hikari-001_052 ===
# ところが、ここ数年はキーを抜いてドアをロックした「キーなし」車の盗難が増加。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_052.wav
# === hikari-001_053 ===
# パキスタンのアフガン政策は、カシミール地方で領有権を争うインドをにらんだものだ。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_053.wav
# === hikari-001_054 ===
# 結局、「イングリッシュ・ペーシェント」は最優秀監督、音楽、美術など十二部門、また「シャイン」も七部門にノミネートされた。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_054.wav
# === hikari-001_055 ===
# ジュゼッペ・デロッソ会長は「イタリアの正統的家庭料理を擁護するために戦う」と宣言。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_055.wav
# === hikari-001_056 ===
# 商店会メンバーを中心に実行委員会をつくり、「元気まつり」と銘打った。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_056.wav
# === hikari-001_057 ===
# 研修ではサトウキビの種苗生産、植え付け、株出し管理、収穫、肥料や病虫害、製糖工程に関するすべてを学ぶ。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_057.wav
# === hikari-001_058 ===
# 森と工場が交互に現れるアウトバーンのドライブとはずいぶん違う。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_058.wav
# === hikari-001_059 ===
# 愛想のいい海の家の亭主が出すラーメンが猛毒の添加物入りでなければいいが。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_059.wav
# === hikari-001_060 ===
# シアトルに本社を置く全米チェーンのコーヒーショップ「スターバックス」のビルなども被害を受けた。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_060.wav
# === hikari-001_061 ===
# 調停作業を続ける保証人委のシプリアニ大司教も十九日、アヤクチョのミサで、双方に異例の「融和」を呼びかけた。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_061.wav
# === hikari-001_062 ===
# アナリエ容疑者のいる前で、武容疑者が「おいしいおやつを持ってきた」と勧め、佐藤さんに食べさせた。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_062.wav
# === hikari-001_063 ===
# 首相は最初に、現在ロスアンゼルス港でレストランに使われているクィーン・メリー号を訪れる。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_063.wav
# === hikari-001_064 ===
# 海上保安庁も後援、各海上保安部やフェリー乗り場などに募金箱を設置し、職員や一般の人たちに協力を呼びかけている。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_064.wav
# === hikari-001_065 ===
# また、兵庫県・淡路島の書店でも「フォーカス」の四ページ分を二枚にコピーし、六十円で約二十部販売していた。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_065.wav
# === hikari-001_066 ===
# タイガー・ウッズ選手の日本ツアー初出場で、プロゴルフのカシオ・ワールドオープンも全国の話題をさらった。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_066.wav
# === hikari-001_067 ===
# タイやヒラメの上品もいいが、脂の乗った塩焼きやつみれの野趣は、イワシならではの味わい。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_067.wav
# === hikari-001_068 ===
# エルニーニョとは南米ペルー沖の海水が異常に高温になる現象で、これが起きると太平洋と沿岸地域に台風の集中発生や集中豪雨、干ばつなどをもたらす。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_068.wav
# === hikari-001_069 ===
# 州最高裁が手集計に「ノー」の判断を下した場合、ゴア氏はいよいよ窮地に立たされる。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_069.wav
# === hikari-001_070 ===
# これに対し、日航は、特定の搭乗日のみ有効な事前購入型運賃「前売りスペシャル」を導入した。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_070.wav
# === hikari-001_071 ===
# 十九歳でショパン国際コンクールに優勝、一躍「天才」と騒がれた。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_071.wav
# === hikari-001_072 ===
# 大きなリュックを持った旅行客がベンチに横たわり、台風通過を待った。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_072.wav
# === hikari-001_073 ===
# 伊藤頭取は「個人の金融資産についてフィナンシャル・アドバイザーが運用や管理の相談を受ける。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_073.wav
# === hikari-001_074 ===
# ところが、やはり注文が細かくて、そのレシピも美由紀さんにはチンプンカンプン。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_074.wav
# === hikari-001_075 ===
# 果たしてイチローとマリナーズはヤンキース越えを果たし、ワールドシリーズまで駆け上がってくれるだろうか。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_075.wav
# === hikari-001_076 ===
# ブレーブスをナ・リーグ有数の強豪に育て上げたコックス監督は、指折り数えながら楽しそうに話し始めた。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_076.wav
# === hikari-001_077 ===
# 父が鼓の家元というスーパーお嬢様の石井さんからは、とても会社を起こすようなバリバリのキャリアウーマンイメージは伝わってこない。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_077.wav
# === hikari-001_078 ===
# 「野球でいうなら、観客から応援団へと変わり、いよいよプレーヤーになってもらうのが二十一世紀」と語る。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_078.wav
# === hikari-001_079 ===
# ペイトリオッツは守備陣が、リーグ一の攻撃力を誇るラムズに大健闘。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_079.wav
# === hikari-001_080 ===
# 「汗取りパウダーのようなにおいがした」という白い粉がこぼれ、ミラー記者の顔、手、セーターに落ちた。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_080.wav
# === hikari-001_081 ===
# 夜間パトロールや「笑顔運動」など地域を守る活動を実施している。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_081.wav
# === hikari-001_082 ===
# ゴアは頭はよいかもしれないけど、大統領選挙は頭のよいやつを選ぶ選挙じゃないからね。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_082.wav
# === hikari-001_083 ===
# 終了後、成田市長は「建設場所を五キロ移すと、環境影響評価をやり直さなければならない。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_083.wav
# === hikari-001_084 ===
# 日本郵船は今秋、東京・丸の内の本社ビル内に保育所を開設、近く運営会社「郵船チャイルドケア」を発足させる。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_084.wav
# === hikari-001_085 ===
# 官房長ポストは、中央省庁で人事や国会対策、経理など総務を統括する要職。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_085.wav
# === hikari-001_086 ===
# また、同市役所や市内の主要な事業所にも「ノーマイカーデー」を呼び掛け、水曜と金曜に自動車通勤をやめてバスを利用することを要請していくという。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_086.wav
# === hikari-001_087 ===
# 「マスジア」や「ハルナ」、釣り鐘状に咲く珍しい品種「八重カシワバアジサイ」など各種アジサイが、白や紫などの色合いで咲き、今が見ごろ。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_087.wav
# === hikari-001_088 ===
# 役作りのため体重を増やしたブリジット役の女優レニー・ゼルウィガーさんが撮影終了後、猛烈なダイエットでやせ、議論に拍車がかかった。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_088.wav
# === hikari-001_089 ===
# おまけに北風がビュービューと吹き荒れて、真冬の奄美よりずっと寒く感じた。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_089.wav
# === hikari-001_090 ===
# ルーチンワークを行う単純労働力は不要になり、多くの中間管理者が失業する。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_090.wav
# === hikari-001_091 ===
# ただ、スピアズが番組最後でデュエットに応じてくれるかどうかは謎だという。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_091.wav
# === hikari-001_092 ===
# パキスタン軍情報機関関係者やタリバン政権のザイーフ駐パキスタン大使らが同行した。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_092.wav
# === hikari-001_093 ===
# じゃあ、私たちもフランスは高級品ばかりというイメージを変えなくちゃ。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_093.wav
# === hikari-001_094 ===
# 次に装管チューブがはずれた場合、それを寿命と考え救命すべきかどうかが倫理委員会にかけられた。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_094.wav
# === hikari-001_095 ===
# 不安になってプリンタ用インクも家にまだひと箱あるが、二箱補充。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_095.wav
# === hikari-001_096 ===
# 生まれ年も同じベビーブーマーだが、両氏の世界観の違いは大きい。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_096.wav
# === hikari-001_097 ===
# そこのところにポイントを絞られたというふうに考えてよろしいんでしょうか。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_097.wav
# === hikari-001_098 ===
# 十一回目の今年度のテーマは「好きなひと」、「読む」、「『百聞』と『一見』」。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_098.wav
# === hikari-001_099 ===
# 恒久減税を求める声にも「恒久的減税」で逃げ、住宅ローン利子控除も見送られた。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_099.wav
# === hikari-001_100 ===
# ヘリテージ財団のイェーツ研究員は、「逆にゴア陣営への有権者の反発を招く可能性がある」との見方だ。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_100.wav
# === hikari-001_101 ===
# 冷戦直後のサミットの場で東欧やロシアを支援する「ヨーロッパ復興開発銀行」が生まれた。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_101.wav
# === hikari-001_102 ===
# その電子制御分野の技術アドバイザーを、三年前に川崎重工業の元電子制御センター所長を最後に退職した伊藤憲治さんが務めた。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_102.wav
# === hikari-001_103 ===
# 「希望ナンバー制」の対象は、新車購入などで新たにナンバープレートが必要となる人。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_103.wav
# === hikari-001_104 ===
# タレント並みに知名度が高い女性アナウンサーには、一日数十通ものファンレターが届くという。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-001_104.wav
#
# >>> processing hikari-002 ...
# === hikari-002_001 ===
# 本間さんは、同地区や細越地区の五十アールの園地に、数種類のプルーンを栽培しており、一部はリンゴ園の防風林代わりにもなっている。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_001.wav
# === hikari-002_002 ===
# ただ同委は、高シェア品目を中心に関税の早期引き下げ・撤廃を要望している。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_002.wav
# === hikari-002_003 ===
# ロケット弾やミサイルをレーザーによって迎撃する兵器は極めて異例。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_003.wav
# === hikari-002_004 ===
# 「たかが、インフルエンザ」と高をくくると、手痛いしっぺ返しを食うことは、スペイン風邪やアジア風邪の歴史が教えている。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_004.wav
# === hikari-002_005 ===
# 青森県をイメージアップするいい機会と思うので返上しないでほしい。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_005.wav
# === hikari-002_006 ===
# 首相は連立政権内の極右政党やユダヤ人入植者団体から、「もっと強硬な措置を」と突き上げを受けていた。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_006.wav
# === hikari-002_007 ===
# 「庭じゅうがヤナギランで埋まればいいですね」と語る久本さん夫妻。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_007.wav
# === hikari-002_008 ===
# 「強いチームにはいいリードオフマンがいる」というイチローの言葉をはからずも裏付けている。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_008.wav
# === hikari-002_009 ===
# 同じようなことわざに「恐ろしければやぶが動く」、「ナスを踏んでカエルと思う」などがある。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_009.wav
# === hikari-002_010 ===
# 米国のうたい文句は「年間コストはキャンデー一個、生涯で虫歯一本の治療費」。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_010.wav
# === hikari-002_011 ===
# ワールドカップ・ヨーロッパ予選のオーストリア対イスラエル戦も、危険を理由に延期された。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_011.wav
# === hikari-002_012 ===
# いっぽう、富士通は課長級以上の管理職の賞与と給与をカットする。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_012.wav
# === hikari-002_013 ===
# 北海道の原生林はヒグマや蝦夷オオカミの棲む野生の森でもあった。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_013.wav
# === hikari-002_014 ===
# 税制個人投資家に対する優遇税制は、申告分離の税率引き下げや売却損の繰り越しが主なポイント。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_014.wav
# === hikari-002_015 ===
# 人権擁護委員、調停委員の活用や暴力夫に対するカウンセリング体制づくりを急ぐべきである。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_015.wav
# === hikari-002_016 ===
# ほとんどはアラビア文字クーファ書体で刻まれたものだが、ギリシャ文字、古代コプト文字、ラテン文字などもあった。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_016.wav
# === hikari-002_017 ===
# このことから、おむつ売り場の横にビール売り場を置いて、売り上げ増。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_017.wav
# === hikari-002_018 ===
# 曜日を決めて掲載されるコラム、エッセー、お知らせ情報の週刊クリックは週初めに。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_018.wav
# === hikari-002_019 ===
# ノルウェーのオスロで港を望む古い城跡を早朝ふらりと歩いたら、その実があちこちに落ちていた。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_019.wav
# === hikari-002_020 ===
# 絵柄は、来年の干支の馬、えびす様や大黒様、招き猫やタイ、ひょっとこなど。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_020.wav
# === hikari-002_021 ===
# その中で「宗教対話の相手としてユダヤ教とイスラム教をまず第一に考える」。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_021.wav
# === hikari-002_022 ===
# 小太り、黒色ジャージー上下姿で、茶色の毛糸帽子にサングラスをかけ無精ひげをはやしていた。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_022.wav
# === hikari-002_023 ===
# 他に「現代ソビエト文学の世界」、「謎とき『カラマーゾフの兄弟』」などもある。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_023.wav
# === hikari-002_024 ===
# 親パキスタンのタリバン穏健派を加えよという従来の主張を繰り返したものだ。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_024.wav
# === hikari-002_025 ===
# 自転車便を舞台にした邦画「メッセンジャー」も上映が始まったばかりで、話題を集めそうだ。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_025.wav
# === hikari-002_026 ===
# 気象庁エルニーニョ監視予報センターは十日、「太平洋赤道域でエルニーニョ現象が始まっている可能性が高い」と発表した。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_026.wav
# === hikari-002_027 ===
# これに対してキャリパー自体が高温になり、ブレーキフルード内に気泡が発生してブレーキ圧力が下がる現象はベーパーロックと言います。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_027.wav
# === hikari-002_028 ===
# 本体やディスプレイ、キーボードが黒色なので見分けにくいが、下の写真を見てほしい。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_028.wav
# === hikari-002_029 ===
# 佐藤信二通産相は二十八日、ワシントンでデーリー商務長官と初めて会談した。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_029.wav
# === hikari-002_030 ===
# 当時、ソ連も含む全戦勝国との全面講和論もあったが、冷戦下、多数講和が唯一の現実策だった。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_030.wav
# === hikari-002_031 ===
# 大喜びした彩果さんは、「バルーンは、おうちでいまもうかんでいます」。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_031.wav
# === hikari-002_032 ===
# ただ、漁業委員会も密漁によるキャビアの漁獲量まではわからない。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_032.wav
# === hikari-002_033 ===
# 関電の「オール電化住宅」はエネルギー需要の頭打ちと規制緩和による競争激化に対応、家庭用エネルギー分野の需要拡大を図る。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_033.wav
# === hikari-002_034 ===
# 「事実が違ったら、そのとき対処を考えますよ」、英国流ユーモアを交えてほほえむ。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_034.wav
# === hikari-002_035 ===
# 主に沖縄本島中南部の農協製品を扱うスーパーや宅配で売られている。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_035.wav
# === hikari-002_036 ===
# この「オリエンタル」の言葉を事実上の差別用語にさせたのは、エドワード・サイード米コロンビア大教授であった。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_036.wav
# === hikari-002_037 ===
# ニューヨーカー誌最新号などによると、エリス氏は開票状況や非公開のはずの出口調査のデータなどをブッシュ陣営に伝えていた。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_037.wav
# === hikari-002_038 ===
# 挑戦者の甘いガードを突いてボディーで前のめりにさせ、すかさずアッパーを放つ理にかなった攻め。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_038.wav
# === hikari-002_039 ===
# 病棟内では「ターニャ」の愛称で呼ばれ、看護婦もロシア語を勉強するなどして看護に当たった。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_039.wav
# === hikari-002_040 ===
# 「操業権」になれば、原油はクウェート政府が所有し、生産委託を受けたアラ石が歩合収入を得る形になる模様だ。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_040.wav
# === hikari-002_041 ===
# オープニングセレモニーでは、名瀬市の平田隆義市長が、「交流展を通じて沖縄、奄美の文化が大きくなってゆくよう願っています」。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_041.wav
# === hikari-002_042 ===
# スプーンでひとさじすくった瞬間、鼻をくすぐる風味は紛れもなく赤ピーマンそのもの。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_042.wav
# === hikari-002_043 ===
# 「テロ組織をそれぞれ打ち負かすまで戦いをやめない」と戦争続行を宣言。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_043.wav
# === hikari-002_044 ===
# 「ウォーム」と呼ばれる種類で、インターネットのウェブサイトで増殖し続ける。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_044.wav
# === hikari-002_045 ===
# 下草、雑草の駆除目的の注文が多いが、情操教育用にメスの子ヤギを頼んだ幼稚園もあった。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_045.wav
# === hikari-002_046 ===
# 強制収容所は戦時下に軍需品を生産するダイムラーベンツやメッサーシュミットなどの生産にも協力した。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_046.wav
# === hikari-002_047 ===
# アイオワ州をブッシュ氏がとっても選挙人は過半数に達せず、当落には影響しない。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_047.wav
# === hikari-002_048 ===
# 同町は今年初めてクジラ・イルカウオッチングフォトコンテストの作品を募集中。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_048.wav
# === hikari-002_049 ===
# 手術した田中裕・救命救急センター助教授は、「命を救えなかった事が今も悔しい」と話した。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_049.wav
# === hikari-002_050 ===
# 同病院では、レーザー照射を用いた気管支の腫瘍除去手術は年に数例行っているが、人工呼吸器で高濃度の酸素を送っての手術は初めてという。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_050.wav
# === hikari-002_051 ===
# 「メタルは重量骨材やクレーン車のバランスウエートとして、溶融スラグは建設ブロック材の原料として再利用している」。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_051.wav
# === hikari-002_052 ===
# 「それが民主主義のルールじゃないかね」といつもながら皮肉っぽい。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_052.wav
# === hikari-002_053 ===
# まだオールスターで本塁打を打ったことがないんで、何とか打ちたい。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_053.wav
# === hikari-002_054 ===
# 圧倒的な軍事力をペルシャ湾周辺に配置し、フセイン政権に圧力をかけた。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_054.wav
# === hikari-002_055 ===
# 各国の民芸品や書籍を扱う店やエスニック料理の屋台も多数出店されるという。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_055.wav
# === hikari-002_056 ===
# 左右のコーナーをいっぱいに使い、打者にストライクゾーンを広く感じさせる投球ができる。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_056.wav
# === hikari-002_057 ===
# 漁業に就きたい人への相談窓口・情報発信拠点として、県漁連は「沿岸漁業就業者確保育成センター」を開設した。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_057.wav
# === hikari-002_058 ===
# 生徒らは慎重にホンテざおを回し、ゆがみが出ないように注意していた。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_058.wav
# === hikari-002_059 ===
# この手法は電力や通信などインフラストラクチャー事業に応用できる。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_059.wav
# === hikari-002_060 ===
# 新潟の女性監禁事件のさなか、温泉で接待マージャンをしていた県警本部長。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_060.wav
# === hikari-002_061 ===
# 融資先の一部はベンチャー企業ではないペーパーカンパニーや、山口組系の暴力団との親交者が経営する不動産会社などだった。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_061.wav
# === hikari-002_062 ===
# 突然、電車動詞が衝突したような「ガーン」という大音響がして、建物が横に大きく揺れた。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_062.wav
# === hikari-002_063 ===
# 亜鉛メッキされた鋼材を、枠組み材として壁などに打ちつけて使うツーバイフォー形式の「スチールハウス」を売り込む動きが、鹿児島県内でも出てきた。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_063.wav
# === hikari-002_064 ===
# 運転手はフェリー内でビールを飲んでいた上、荷台は過積載だった。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_064.wav
# === hikari-002_065 ===
# まず、日本陸連が「保留」という表現を使った点がキーポイントだ。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_065.wav
# === hikari-002_066 ===
# 「粘りが強い須賀川特産の『にぎり芋』を、カツオだしのみそ汁を混ぜてすり下ろす。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_066.wav
# === hikari-002_067 ===
# しかし、デビュー当初はリングで力を出せない「チキンハート」でもあった。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_067.wav
# === hikari-002_068 ===
# バトル閣外相は、英国の駐ミャンマー大使が先週末、スーチーさん周辺と連絡を取ろうとして当局から「手荒な行為」を受けたと抗議。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_068.wav
# === hikari-002_069 ===
# ショールームとは、クリエイターたちが作品を展示し、バイヤーたちが買いつけに訪れる場。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_069.wav
# === hikari-002_070 ===
# 日本代表団筋は「オブザーバーが同席している場合と、そうでない場合、交渉の空気はやはり違う」と認めている。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_070.wav
# === hikari-002_071 ===
# チューリップ、マーガレット、フリージアやプリムラなど、五十種九千株の春の花が美しさを競うように色鮮やかに輝き、春の息吹を感じさせる。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_071.wav
# === hikari-002_072 ===
# 長引く不況で雇用情勢が悪化するなかパートタイマーや派遣社員が増え続けている。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_072.wav
# === hikari-002_073 ===
# 職場では「パソコンの切り方知らずプラグ抜く」とパソコン導入などの環境の変化に右往左往。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_073.wav
# === hikari-002_074 ===
# ところが、すきすき状態はフリーウェイだけではなく、ホテルも同様。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_074.wav
# === hikari-002_075 ===
# いま、ようやくドーム病を克服し、新しい強竜打線が誕生しつつあるのです。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_075.wav
# === hikari-002_076 ===
# 四十二年には第一弾として海水浴場やキャンプ場、レストハウスなどを備えた「無人島パラダイス」をオープンした。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_076.wav
# === hikari-002_077 ===
# 今年五月、カンガルー杯国際女子オープンテニスのシングルス初戦で敗れた県岐阜商二年の市川歩は、こぼれ落ちる涙を止められなかった。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_077.wav
# === hikari-002_078 ===
# ラグーンの豊富な栄養塩がアドリア海の生産性を支えており、漁業への影響はさらに広範囲に及ぶとみている。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_078.wav
# === hikari-002_079 ===
# イラク国営テレビが放映したもので、フセイン大統領は八人のボディーガードをお供に元気に三回、川を泳ぎ切った。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_079.wav
# === hikari-002_080 ===
# 同博物館にはほかにもハンググライダーや小型の双発ジェット機、実験機「飛鳥」など、多数のシミュレーターがある。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_080.wav
# === hikari-002_081 ===
# 両陛下はまずジュネーブ入りし、国際赤十字委員会などを訪問する。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_081.wav
# === hikari-002_082 ===
# しかし、集計地域は不明で、与党優位のセルビア南部を中心とする数値と見られる。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_082.wav
# === hikari-002_083 ===
# アルコールは、糖尿病を患っている三浦容疑者がインシュリンを注射する際に腕に塗るものだったらしい。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_083.wav
# === hikari-002_084 ===
# 雪山で死んだフィアンセが忘れられず、彼女は彼が昔に住んでいた住所にラブレターを出す。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_084.wav
# === hikari-002_085 ===
# 政治ではないけれど、官僚さんのことを書いた本でイチ押しなのが、テリー伊藤著・お笑い大蔵省。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_085.wav
# === hikari-002_086 ===
# この度は、横浜ベイスターズの監督就任おめでとうございます。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_086.wav
# === hikari-002_087 ===
# 彼女の恋人とはオックスフォードのカレッジ出身のエリートながら、頼りなさげなヒュー・グラント。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_087.wav
# === hikari-002_088 ===
# 研修会では県政策マーケティング委員会委員長の中橋勇一氏が、「行政評価の重要性」と題して講演、評価を数値で示すことの重要性などを強調した。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_088.wav
# === hikari-002_089 ===
# 強者優遇、それでは、消費者にとってビッグバンは歓迎できるものになるのか。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_089.wav
# === hikari-002_090 ===
# 泉質はナトリウム炭酸水素塩・塩化物温泉で、神経痛や筋肉痛などに効能がある。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_090.wav
# === hikari-002_091 ===
# 当初の内容は会社概要、事業案内、プレゼント付きアンケートなど。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_091.wav
# === hikari-002_092 ===
# 輸出の狙いは「県産米の販路拡大と知名度アップ、それに生産者の意欲を高める面も大きい」と矢萩次長。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_092.wav
# === hikari-002_093 ===
# いわゆる「和田移植」事件を契機に、臓器移植はタブー視されるようになってしまったわけです。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_093.wav
# === hikari-002_094 ===
# また、組合員たちがカンパして持参した大量の鉛筆やノートなどの文房具類、鍵盤ハーモニカ約五十台も贈り、子供たちは大喜びだった。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_094.wav
# === hikari-002_095 ===
# あんまりおもしろいんでたくさんのバージョンでマンガ化されているね。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_095.wav
# === hikari-002_096 ===
# 飲酒の強要、イッキ飲ませ、酔ってからむといった、お酒にまつわる嫌がらせや人権侵害のことである。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_096.wav
# === hikari-002_097 ===
# 重油流出事故では昭和四十九年の三菱石油水島製油所事故の約七千九百トン流出に次ぐ大規模事故になりそう。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_097.wav
# === hikari-002_098 ===
# あんなにクレバーで、ユーモアがあって、サッカーを愛し、勝負に厳しい人は俺は他には知らないよ。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_098.wav
# === hikari-002_099 ===
# 高齢化のピッチが速いが故、高齢者の交通安全対策に一刻の猶予も許されない。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_099.wav
# === hikari-002_100 ===
# インフォメーションは、分析・統合されて初めてインテリジェントとなる。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_100.wav
# === hikari-002_101 ===
# サム・リャンシー党は、「人民党の独裁に嫌気がさし、住民が変化を求めた」。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_101.wav
# === hikari-002_102 ===
# 東京・八重洲の観光物産サービスセンター内の店舗が十三年度いっぱいでの立ち退きを迫られている。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_102.wav
# === hikari-002_103 ===
# そのうえで、環境税などエネルギー関連税制の導入を「検討に値する」と評価する。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_103.wav
# === hikari-002_104 ===
# 裏手の従業員専用入り口から同支店と同センターが入居する社屋二階に入った。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_104.wav
# === hikari-002_105 ===
# アンナ・カバレーロ市長の歓迎を受けた一行は、両市の友好関係が長く続くことを願い、議事堂わきに桜を植樹。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-002_105.wav
#
# >>> processing hikari-003 ...
# === hikari-003_001 ===
# 若者が狙われやすい「アポイントメントセールス」は六十八件で、同十件増となっているなど増加傾向を見せている。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-003_001.wav
# === hikari-003_002 ===
# 鹿児島市の天文館の歩道で、若い女性が片方の靴を脱ぎ、かかとをティッシュペーパーでふいていた。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-003_002.wav
# === hikari-003_003 ===
# どうやら彼女のお母さんは関西では聞こえたゴルファーだったらしい。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-003_003.wav
# === hikari-003_004 ===
# 旧家に間借りしていた学生は以前もいたが、ワンルームマンションができて、人数は大きく増えた。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-003_004.wav
# === hikari-003_005 ===
# 自己最高位だからうれしいことはうれしいんですけど、レース直後は、すごく落ち込みましたね。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-003_005.wav
# === hikari-003_006 ===
# 電機は三年連続でベア五百円にとどまったが、金属産業全体では昨年実績をやや上回っている。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-003_006.wav
# === hikari-003_007 ===
# 体力的なハンディを、武蔵丸ら大力士が多い武蔵川部屋への出げいこで補った。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-003_007.wav
# === hikari-003_008 ===
# 車についての捜査は、県内の軽ワンボックス車四万六千台のうち、青森ナンバーの全車両約二万七千台を抽出、これまで約二万一千台の捜査を終了。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-003_008.wav
# === hikari-003_009 ===
# この歌がいかにも南島の雰囲気を醸すのは、ヒュイ、ヒュイと鳴る指笛の効果だ。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-003_009.wav
# === hikari-003_010 ===
# ダイエーは先発候補の新外国人投手ウエストが球威不足で不安を残した。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-003_010.wav
# === hikari-003_011 ===
# 今月五日死去したノーベル平和賞受賞者の修道女、マザー・テレサの葬儀が十三日、インドのカルカッタで国葬として行われる。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-003_011.wav
# === hikari-003_012 ===
# ルールを破っても戦力をアップさせ、勝ったチームがよしとされる。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-003_012.wav
# === hikari-003_013 ===
# 指定を受けた組織のメンバーは、ビザ発給拒否や国外退去処分などの対象になる。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-003_013.wav
# === hikari-003_014 ===
# いやー、実はあがり症でさと言いつつ、なかなかシブい声で素敵でした。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-003_014.wav
# === hikari-003_015 ===
# これからもこの海域でばかげた「レジャーランド・ツアー」を続けるのか。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-003_015.wav
# === hikari-003_016 ===
# ウエッブサイトは、マスコミと読者と筆者が、自由に交流できる未来性のある情報空間です。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-003_016.wav
# === hikari-003_017 ===
# 「一定時間お手伝いをするバランスのよい日常生活が、キレを防ぐ有効な手段になるはずだ」と話している。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-003_017.wav
# === hikari-003_018 ===
# フェンディの売上が上がったけど、ルイヴィトンの売上が落ちたのでは意味がありませんから。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-003_018.wav
# === hikari-003_019 ===
# 一般団体の部で最高の「宇宙遊泳賞」に輝いたのは、植物園カンナの作品。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-003_019.wav
# === hikari-003_020 ===
# 大統領は別れ際に「私の父親とも関係があったのか」と尋ね、ディートリヒは「いいえ」と答えた。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-003_020.wav
# === hikari-003_021 ===
# 爆発した火薬置き場の施設は、ぐにゃぐにゃに曲がった鉄骨スレートが数本残っているだけ。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-003_021.wav
# === hikari-003_022 ===
# とうさんヒョウは、ジャングルの川にそって、上へ上へのぼりました。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-003_022.wav
# === hikari-003_023 ===
# 一部がフェンスを乗り越えようとしたため、イスラエル兵士がゴム弾を威嚇発砲した。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-003_023.wav
# === hikari-003_024 ===
# 党改革では中央と地方組織が密接になるよう推進し、総裁選も今後同じルールで行うようにすべきだ。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-003_024.wav
# === hikari-003_025 ===
# アンケート用紙は持ち帰ってファクスや郵送でも回答できるようになっており、街頭分と合わせて約八百人の声を集める。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-003_025.wav
# === hikari-003_026 ===
# 会議は野菜などの混ぜ合わせの代表的な沖縄料理「チャンプルー」をもう一つのキーワードに展開した。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-003_026.wav
# === hikari-003_027 ===
# 当選者がいない場合の賞金は、翌週の賞金に加算される「キャリーオーバー制」を日本で初めて採り入れた。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-003_027.wav
# === hikari-003_028 ===
# 「みゆき野に輝け友情集う技」を大会スローガンに、第五十六回冬季スキー国体「ながの飯山国体」が十八日、長野県飯山市で開幕する。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-003_028.wav
# === hikari-003_029 ===
# このため「子供部屋へは必ずリビングを通って行く間取り」を望んでいる。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-003_029.wav
# === hikari-003_030 ===
# 日立は潮の流れが速い場所なので、水中ウキを使用し、感度のよい棒ウキを使うようにして下さい。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-003_030.wav
# === hikari-003_031 ===
# 県内の高校野球ファンは最終回まで手に汗にぎる展開に、テレビにくぎ付けとなって一喜一憂。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-003_031.wav
# === hikari-003_032 ===
# 連合鹿児島の香川紀征会長は「ようやくユニオンを結成することができた」。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-003_032.wav
# === hikari-003_033 ===
# これは第三世代フェレット・サービスシステムとも言うべき画期的な提案なのである。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-003_033.wav
# === hikari-003_034 ===
# ライフプランより先に考えなければいけない重要なことがあるのをすっかり忘れていた。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-003_034.wav
# === hikari-003_035 ===
# 西武遊園地駅の駅員は、男性乗客から「人がホームに倒れている」との通報で事件を知った。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-003_035.wav
# === hikari-003_036 ===
# 勝ち誇ったように腕を突き上げ、ひわいな言葉を投げかけて退場したインは、関係者に噛みつき行為までみせていた。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-003_036.wav
# === hikari-003_037 ===
# 昨年から里親を募る一方、ポスターやチラシを全国に発送、留学生を募集していた。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-003_037.wav
# === hikari-003_038 ===
# これまで欧米やアジア諸国を訪ねており、中国を訪ねるのは二回目だという。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-003_038.wav
# === hikari-003_039 ===
# その後も首を持ち上げて「ピーピー」と鳴きながらえさをねだり、元気な様子を見せている。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-003_039.wav
# === hikari-003_040 ===
# 事務所は無人のことが多く、連絡は電話代行サービスに依頼していたという。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-003_040.wav
# === hikari-003_041 ===
# これにより、ほんの数分ほどで自分のニーズにぴったりの商品が探せるというわけだ。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-003_041.wav
# === hikari-003_042 ===
# ペイオフの対象になる定期預金を解約して、普通預金や国債購入などに分散。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-003_042.wav
# === hikari-003_043 ===
# スーパーボウル、大リーグでワールドシリーズに出場した唯一の選手として知られている。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-003_043.wav
# === hikari-003_044 ===
# 地域別に見ると、特に東南アジア及び欧米の観光地において顕著である。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-003_044.wav
# === hikari-003_045 ===
# 基金の拠出に応じる見通しなのは三井住友銀行のほか、複数の三井グループ企業など。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-003_045.wav
# === hikari-003_046 ===
# たばこのニコチンや一酸化炭素は、高脂血症や動脈硬化を引き起こす誘因があるだけでなく、さまざまな病気の引き金になっている。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-003_046.wav
# === hikari-003_047 ===
# 鹿児島市城南町の市中央卸売市場魚類市場が、初ガツオの入荷で活気づいている。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-003_047.wav
# === hikari-003_048 ===
# 特にメガワティ大統領の夫であるウフィック議員が政策決定や重要人事に露骨に介入し、政権内に確執と混乱を生んでいる。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-003_048.wav
# === hikari-003_049 ===
# 山田さんは神戸市出身で、灘中学ワンダーフォーゲル部時代に山の楽しさに魅せられた。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-003_049.wav
# === hikari-003_050 ===
# 五十台の主婦は「早く新しい店がオープンしてほしい」と話していた。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-003_050.wav
# === hikari-003_051 ===
# がっかりして港に戻り、桟橋でトビウオをすくう島の人たちを見て周った。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-003_051.wav
# === hikari-003_052 ===
# その後リーダーの退社で、浜中被告は損失補てんの重圧を一手に背負う。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-003_052.wav
# === hikari-003_053 ===
# アメリカの首都ワシントンでは、冷雨の下、ブッシュ大統領が就任した。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-003_053.wav
# === hikari-003_054 ===
# 昨年、家族三人で神戸を歩いた時、三宮の駅前にあるフェニックスプラザで「震災モニュメントマップ」を見つけた。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-003_054.wav
# === hikari-003_055 ===
# 同市中山町のケーズデンキ谷山パワフル館でも、対象目の買い替えは途絶えたという。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-003_055.wav
# === hikari-003_056 ===
# 鹿児島の花は輪ギクのイメージが強かったが、スプレーギクや洋花など新しいイメージも県外へ打ち出してほしい。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-003_056.wav
# === hikari-003_057 ===
# それからおよそ四半世紀たった現在、持ち家の広さでは独、仏、英など、ヨーロッパの先進国の平均をかなり上回るようになった。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-003_057.wav
# === hikari-003_058 ===
# 遊歩道の足場はテトラとなっているので、初心者の夜釣りはお勧めできません。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-003_058.wav
# === hikari-003_059 ===
# 今人気の、まだ十代のソプラノ歌手シャルロット・チャーチが天使だとすると、エディタ・グルベローヴァはまさに女神である。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-003_059.wav
# === hikari-003_060 ===
# 静止ホイールはホイールの軸に特殊ベアリングを使用、回転しないよう重りをつけ動かないようにした。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-003_060.wav
# === hikari-003_061 ===
# 市のほかで仕事を探さないと経営が危なくなると悲鳴を上げ、旧大宮市職員は「いずれは旧浦和の人が主要ポストに就くのでは」。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-003_061.wav
# === hikari-003_062 ===
# このため、シーメンスとの提携をテコに次世代携帯で欧州市場へ参入したい考えだ。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-003_062.wav
# === hikari-003_063 ===
# 会見に先立ち、福田長官は、ブルネイ入りした森首相と電話連絡を取った。
# ...
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_003.wav
# === hikari-089_004 ===
# 女児は「ドゥーハ」と命名された。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_004.wav
# === hikari-089_005 ===
# 対話はもはや、宥和政策になりつつあります。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_005.wav
# === hikari-089_006 ===
# 「十分手応えはある」と意気込んだ。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_006.wav
# === hikari-089_007 ===
# 麻生外相は15日のテレビ出演でこう力説した。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_007.wav
# === hikari-089_008 ===
# 2004年にはパラナ州名誉州民となった。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_008.wav
# === hikari-089_009 ===
# ロワイヤル氏の討論内容について、フランスソワール紙は「防御的だった」と批判。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_009.wav
# === hikari-089_010 ===
# 開発には、P2P型ファイル共有ソフト「Winny」の作者である金子勇氏も参画。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_010.wav
# === hikari-089_011 ===
# 心に残るミュージカル映画は？イオンは優先交渉権を踏まえ、ダイエーのデューディリジェンス（資産査定）に着手。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_011.wav
# === hikari-089_012 ===
# 論文を出したのは、米ジョンズ・ホプキンス大医学部のギルバート・バーンハム教授ら4人。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_012.wav
# === hikari-089_013 ===
# 9月日朝首脳、平壌宣言に署名。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_013.wav
# === hikari-089_014 ===
# 3位《江口洋介》も、フジテレビのドラマ「救命病棟24時」シリーズで救急医療センターの敏腕医師を熱演。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_014.wav
# === hikari-089_015 ===
# 瀋陽軍区所属の車両化歩兵旅団は9月上旬、長白山周辺で「全兵力と軍備を動員」した総合訓練も行った。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_015.wav
# === hikari-089_016 ===
# 10月ケリー米特使訪朝。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_016.wav
# === hikari-089_017 ===
# 販売業者の多くは、違法コピー対策プログラム「ウィンドウズ・ジェニュイン・アドバンテージ」を通じて特定。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_017.wav
# === hikari-089_018 ===
# 米コンピューター大手ヒューレット・パッカードは、カナダのパソコンメーカー「ブードゥーPC」を買収すると発表した。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_018.wav
# === hikari-089_019 ===
# 米食品・飲料大手ペプシコのニューイ最高経営責任者、2006年の利益見通しを引き上げ。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_019.wav
# === hikari-089_020 ===
# コーンバーグ教授の父親は、DNAを合成する酵素DNAポリメラーゼを発見した業績で、1959年にノーベル医学生理学賞を受けたアーサー・コーンバーグ氏。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_020.wav
# === hikari-089_021 ===
# 同省北米局長やポーランド大使を歴任。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_021.wav
# === hikari-089_022 ===
# 製薬のシャイア・ファーマスーティカルズが15％高と上げを主導。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_022.wav
# === hikari-089_023 ===
# 米共和党のデボラ・プライス下院議員（オハイオ州）、マーク・フォーリー前下院議員（フロリダ州）との親交を問われ、再選が危ぶまれる。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_023.wav
# === hikari-089_024 ===
# 細い肩ヒモのトップも野暮だ。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_024.wav
# === hikari-089_025 ===
# ハワイ島やオアフ島で停電になったほか、ハワイ島では地滑りも起きた。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_025.wav
# === hikari-089_026 ===
# モーリシャス籍のファンドの運用は、プルーデンシャルICICIアセット・マネジメントから投資助言を受け、PCAアセットが行う。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_026.wav
# === hikari-089_027 ===
# 全モデルがFireWire800ポートを装備する。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_027.wav
# === hikari-089_028 ===
# 「吉野家」の豚丼PRキャラクター「吉ブー」が今月末で姿を消す。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_028.wav
# === hikari-089_029 ===
# コンプレッサー搭載のワインクーラーV-40-Sは40本のワインを収納可能となっている。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_029.wav
# === hikari-089_030 ===
# M＆A助言会社の上場は初めて。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_030.wav
# === hikari-089_031 ===
# 米紙ウォールストリート・ジャーナルのインタビューに答えた。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_031.wav
# === hikari-089_032 ===
# フランスのジャン・ルソーの日本直営店「アトリエ・ジャン・ルソー」は、2006年11月から、高級腕時計ストラップのオーダーメード製造を本格的に開始する。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_032.wav
# === hikari-089_033 ===
# ホセ・ロペス会長兼社長は同日付でネスレS．A．の執行副社長に就く。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_033.wav
# === hikari-089_034 ===
# 日本で言えば震度4程度。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_034.wav
# === hikari-089_035 ===
# ITUの内海善雄事務総局長が明らかにした。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_035.wav
# === hikari-089_036 ===
# ジョン・フェアファックスは、豪州でシドニー・モーニング・ヘラルド紙やエイジ紙などを発行している。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_036.wav
# === hikari-089_037 ===
# ビザ・ヨーロッパは組み込まない。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_037.wav
# === hikari-089_038 ===
# 9月全国CPIは予想より若干弱めとなった。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_038.wav
# === hikari-089_039 ===
# 米国の処方調剤のシェア25％超を掌握する巨大企業が誕生へ。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_039.wav
# === hikari-089_040 ===
# 鉄条網などはない。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_040.wav
# === hikari-089_041 ===
# ウィンストン・チャーチルが米ミズーリ州フルトンで、冷戦の始まりを警告してから5年後。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_041.wav
# === hikari-089_042 ===
# 「そう考えている」とゴーン氏は言う。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_042.wav
# === hikari-089_043 ===
# 後任は、スティーブン・ヘムズリー最高執行責任者（COO）兼社長。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_043.wav
# === hikari-089_044 ===
# 社員がみんなポロシャツとハッシュパピーで、のそのそ歩いているオフィスよりは、ずっと面白い。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_044.wav
# === hikari-089_045 ===
# 同行する企業は、ホーム・デポ、自動車部品メーカーのティムケン、ウェスチングハウス、ルーセント・テクノロジーズなど。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_045.wav
# === hikari-089_046 ===
# 六つのパラスは、プラザアテネ、ジョルジュサンク、リッツ、ブリストル、クリヨン、ムーリス。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_046.wav
# === hikari-089_047 ===
# 米ニューヨーク州のスピッツァー司法長官、同州知事戦での勝利が濃厚。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_047.wav
# === hikari-089_048 ===
# 欧州連合(EU)ではこのところ、オープンソースに関して、公共機関向け情報ポータルの拡張版。
# +++++ cannot generate audio +++++
# === hikari-089_049 ===
# バンダイは、携帯ゲーム機「たまごっち」シリーズの新製品、「たまごっちスクール生徒全員しゅーごっち」を発表。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_049.wav
# === hikari-089_050 ===
# 興銀第一ライフ・アセットマネジメントは、「DIAM短期公社債オープン」を10月30日に設定する。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_050.wav
# === hikari-089_051 ===
# 各パッケージに含まれる製品は、最上位版パッケージの「アルティミット」が、Word、Excel、Outlook、PowerPoint、Access、Publisher、Groove、OneNote、InfoPath、InterConnectの10製品。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_051.wav
# === hikari-089_052 ===
# 欧州の航空機・防衛大手EADS傘下のエアバス、中国に組立工場建設へ。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_052.wav
# === hikari-089_053 ===
# 特にエチオピアのソマリア関与は顕著で、法廷会議は既にエチオピアに対し「聖戦」を宣言。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_053.wav
# === hikari-089_054 ===
# 雑誌の名前は「マネージメント・トゥデー」。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_054.wav
# === hikari-089_055 ===
# 式典には陳総統、蘇貞昌・行政院長ら党指導者のほか、12月の台北、高雄両市長選候補の謝長廷・前行政院長と、陳菊・前労働委員会主任委員が出席し、党勢立て直しへの決意を表明。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_055.wav
# === hikari-089_056 ===
# 対応OSはWindows98以降、MacOSXv10.2以降、Linuxカーネル2.2.14以降。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_056.wav
# === hikari-089_057 ===
# 2位のKDDIも負けてはいない。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_057.wav
# === hikari-089_058 ===
# エールフランスKLM、イベリア航空、ブリティッシュ・エアウェイズが1．5―2．3％の範囲の上げ幅になった。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_058.wav
# === hikari-089_059 ===
# 西部のノルトライン・ウェストファーレン州の出身だという。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_059.wav
# === hikari-089_060 ===
# USW加盟労組員は1万5000人。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_060.wav
# === hikari-089_061 ===
# 一方、リオ・ティントは小幅高、BHPビリトンはほぼ変わらずとなった。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_061.wav
# === hikari-089_062 ===
# さらに航空機用のデュアルプラグアダプタが付属する。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_062.wav
# === hikari-089_063 ===
# バーレーンの米海軍中央指令部報道官は、同盟軍は慎重な予防措置をとっている。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_063.wav
# === hikari-089_064 ===
# 広義流動性は、ロイターの事前予測どおり前年比2．0％増となった。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_064.wav
# === hikari-089_065 ===
# デバイスタイルは、ペルチェ素子を使用したワインセラーとワインクーラーを発表した。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_065.wav
# === hikari-089_066 ===
# 商業捕鯨の認可はノルウェーに続く動き。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_066.wav
# === hikari-089_067 ===
# ウィルコムは、シャープ製スマートフォンの新製品を11月16日に、ピクセラ製のワンセグチューナーを12月5日に発売すると発表した。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_067.wav
# === hikari-089_068 ===
# ヘネシー最大のお得意様なのだそうだ。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_068.wav
# === hikari-089_069 ===
# インターネット通販の普及で、買い物代や旅行代など10万円超の現金を、ATMを通じて振り込む例は多い。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_069.wav
# === hikari-089_070 ===
# アングロアメリカン<AAL>の新CEOにシンシア・キャロル氏が就任へ。
# +++++ cannot generate audio +++++
# === hikari-089_071 ===
# リアルは対ドルで1ドル=3．7420リアルを付けた。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_071.wav
# === hikari-089_072 ===
# メディア調査会社マクアルパイン・アンド・アソシエーツのデニス・マクアルパイン氏は指摘する。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_072.wav
# === hikari-089_073 ===
# 遠隔教育を専門とする英国のOpen Universityは、無料のeラーニングコース「Open Learn」を開始した。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_073.wav
# === hikari-089_074 ===
# SMAPとTOKIOの両リーダーはトーク上手、歌にドラマに大活躍のジャニーズタレント。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_074.wav
# === hikari-089_075 ===
# スワップ金利は、前日夕方に比べて中短期ゾーンが1．0─2．5ベーシス・ポイント程度、長期ゾーンが1．0─0．5bp程度の上昇、超長期ゾーンが0．5bp程度の低下となった。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_075.wav
# === hikari-089_076 ===
# 独ティッセンクルップは米鉄鋼ニューコアによる買収の可能性を手がかりに2．7％上昇。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_076.wav
# === hikari-089_077 ===
# 米ウォルマート・ストアーズ、中国のハイパーマーケットを約10億ドルで買収することで合意。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_077.wav
# === hikari-089_078 ===
# 会見には、ドラノエ・パリ市長やドヌデュードバーブル文化・通信相も同席した。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_078.wav
# === hikari-089_079 ===
# 扇氏はウー・パンクオ全国人民代表大会常務委員長の招きで訪中した。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_079.wav
# === hikari-089_080 ===
# 平均寿命は40歳を下回っている。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_080.wav
# === hikari-089_081 ===
# 政府は毛派に清掃用車両やほうき、シャベルを貸与して協力した。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_081.wav
# === hikari-089_082 ===
# 米不動産大手クッシュマン・アンド・ウェイクフィールド社は25日、世界の目抜き通りの商業用スペースの賃貸料ランキングを発表した。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_082.wav
# === hikari-089_083 ===
# これに伴い、最高購買責任者ジョン・パターソン氏のオフィスも米国ニューヨーク州から中国に移転される。
# [sudo] password for akikun: Normal file mode. Using encoding: 2
# Successfully created file hikari-089_083.wav
# === hikari-089_084 ===
# 標準のフォントファミリーはビット・ストリーム・ベラから派生した「デジャブ」に変更され、デスクトップ全体のルック&フィールが向上した。
# /bin/bash: フィールが向上した。: command not found
# -----------------------------------------------------------------
# FileNotFoundError               Traceback (most recent call last)
# ~/miniconda3/envs/nele/lib/python3.8/shutil.py in move(src, dst, copy_function)
#     787     try:
# --> 788         os.rename(src, real_dst)
#     789     except OSError:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/usr/vt/result/vthenrik/hikari-089_084.wav' -> '/home/akikun/Projects/nele/hikari_tts/wavs/hikari-089_084.wav'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError               Traceback (most recent call last)
# <ipython-input-7-dffff116c74b> in <module>
#      17
#      18         if check_charactors(txt):
# ---> 19             tts_hikari(txt, os.path.join(tts_dir, 'wavs', basename + '.wav'))
#      20             with open(os.path.join(tts_dir, 'scripts', basename + '.txt'), 'w') as f:
#      21                 f.write(txt)
#
# <ipython-input-2-5208da0e7654> in tts_hikari(text_to_read, wav_path, voice, vt_dir)
#      26     # copy the wav file to the desired location.
#      27     wav_path_ = os.path.join(vt_dir, 'result', 'vthenrik', os.path.basename(wav_path))
# ---> 28     shutil.move(wav_path_, wav_path)
#
# ~/miniconda3/envs/nele/lib/python3.8/shutil.py in move(src, dst, copy_function)
#     800             rmtree(src)
#     801         else:
# --> 802             copy_function(src, real_dst)
#     803             os.unlink(src)
#     804     return real_dst
#
# ~/miniconda3/envs/nele/lib/python3.8/shutil.py in copy2(src, dst, follow_symlinks)
#     430     if os.path.isdir(dst):
#     431         dst = os.path.join(dst, os.path.basename(src))
# --> 432     copyfile(src, dst, follow_symlinks=follow_symlinks)
#     433     copystat(src, dst, follow_symlinks=follow_symlinks)
#     434     return dst
#
# ~/miniconda3/envs/nele/lib/python3.8/shutil.py in copyfile(src, dst, follow_symlinks)
#     259         os.symlink(os.readlink(src), dst)
#     260     else:
# --> 261         with open(src, 'rb') as fsrc, open(dst, 'wb') as fdst:
#     262             # macOS
#     263             if _HAS_FCOPYFILE:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/usr/vt/result/vthenrik/hikari-089_084.wav'

# %%
filelist[46]
# Out:
# 'hikari-089'
