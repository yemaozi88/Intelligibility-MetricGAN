# %%
import os
import sys
import glob
import librosa
import numpy as np
import soundfile as sf

repos_dir = r'/home/takkan/repos'
sys.path.append(repos_dir)
from sak import display as dp
from sak import signal_processing as sp
from sak import nele

from pesq import pesq

import IPython.display
from IPython.display import display
import librosa.display

# %%
wavDir_in  = r'/home/takkan/experiments/test_pesq_audio'

input_wav_paths = glob.glob(os.path.join(wavDir_in, '*.wav'))
input_wav_paths.sort()
print(len(input_wav_paths))
for i in range(len(input_wav_paths)):
    print(i, input_wav_paths[i])
# Out:
# 14
# 0 /home/takkan/experiments/test_pesq_audio/audio_speech.wav
# 1 /home/takkan/experiments/test_pesq_audio/audio_speech_bab_0dB.wav
# 2 /home/takkan/experiments/test_pesq_audio/demo_ssdrc_vs_imgan_hikari-003_057_quiet_clean.wav
# 3 /home/takkan/experiments/test_pesq_audio/demo_ssdrc_vs_imgan_hikari-003_057_quiet_imgan.wav
# 4 /home/takkan/experiments/test_pesq_audio/demo_ssdrc_vs_imgan_hikari-003_057_quiet_ssdrc.wav
# 5 /home/takkan/experiments/test_pesq_audio/demo_ssdrc_vs_imgan_hikari-003_057_snr-10_clean.wav
# 6 /home/takkan/experiments/test_pesq_audio/demo_ssdrc_vs_imgan_hikari-003_057_snr-10_imgan.wav
# 7 /home/takkan/experiments/test_pesq_audio/demo_ssdrc_vs_imgan_hikari-003_057_snr-10_ssdrc.wav
# 8 /home/takkan/experiments/test_pesq_audio/demo_ssdrc_vs_imgan_hikari-003_057_snr0_clean.wav
# 9 /home/takkan/experiments/test_pesq_audio/demo_ssdrc_vs_imgan_hikari-003_057_snr0_imgan.wav
# 10 /home/takkan/experiments/test_pesq_audio/demo_ssdrc_vs_imgan_hikari-003_057_snr0_ssdrc.wav
# 11 /home/takkan/experiments/test_pesq_audio/demo_ssdrc_vs_imgan_hikari-003_057_snr10_clean.wav
# 12 /home/takkan/experiments/test_pesq_audio/demo_ssdrc_vs_imgan_hikari-003_057_snr10_imgan.wav
# 13 /home/takkan/experiments/test_pesq_audio/demo_ssdrc_vs_imgan_hikari-003_057_snr10_ssdrc.wav

# %% [markdown]
# # caluculate pesq score for demo sample

# %%
print(input_wav_paths[0])
sample_signal_clean, sample_sr_clean = sf.read(input_wav_paths[0])
print(len(sample_signal_clean),sample_signal_clean, sample_sr_clean)

print(input_wav_paths[1])
sample_signal_noise, sample_sr_noise = sf.read(input_wav_paths[1])
print(len(sample_signal_noise), sample_signal_noise, sample_sr_noise)
# Out:
# /home/takkan/experiments/test_pesq_audio/audio_speech.wav
# 49600 [ 0.          0.          0.         ... -0.00036621 -0.00033569
#  -0.00027466] 16000
# /home/takkan/experiments/test_pesq_audio/audio_speech_bab_0dB.wav
# 49600 [ 0.02633667  0.03024292  0.04083252 ... -0.00253296 -0.01452637
#  -0.00897217] 16000

# %%
print(pesq(sample_sr_clean, sample_signal_clean, sample_signal_noise, 'wb'))
print(pesq(sample_sr_clean, sample_signal_clean, sample_signal_noise, 'nb'))
# Out:
# 1.0832337141036987
# 1.6072081327438354

# %% [markdown]
# # caluculate pesq score for clean

# %%
print(input_wav_paths[2])
#signal_clean = sp.load_wav(input_wav_paths[2])
signal_clean, signal_sr_clean = librosa.load(input_wav_paths[2], sr=16000)
print(len(signal_clean),signal_clean,signal_sr_clean)

print(input_wav_paths[5])
#signal_snr_10 = sp.load_wav(input_wav_paths[5])
signal_snr_10, signal_sr_snr_10 = librosa.load(input_wav_paths[5], sr=16000)
print(len(signal_snr_10),signal_snr_10,signal_sr_snr_10)
# Out:
# /home/takkan/experiments/test_pesq_audio/demo_ssdrc_vs_imgan_hikari-003_057_quiet_clean.wav
# 131209 [ 2.7779619e-08 -3.4310112e-08  4.0996007e-08 ...  0.0000000e+00
#   0.0000000e+00  0.0000000e+00] 16000
# /home/takkan/experiments/test_pesq_audio/demo_ssdrc_vs_imgan_hikari-003_057_snr-10_clean.wav
# 131147 [ 0.05443845 -0.04105372  0.01293906 ... -0.0679858  -0.04244706
#   0.        ] 16000

# %%
display(IPython.display.Audio(signal_clean, rate=signal_sr_clean))
display(IPython.display.Audio(signal_snr_10, rate=signal_sr_snr_10))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print(pesq(signal_sr_clean, signal_clean, signal_snr_10, 'wb'))
print(pesq(signal_sr_clean, signal_clean, signal_snr_10, 'nb'))
# Out:
# 1.0304077863693237
# 1.0665637254714966

# %% [markdown]
# # caluculate pesq score for imgan

# %%
print(input_wav_paths[3])
#signal_clean = sp.load_wav(input_wav_paths[3])
signal_clean, signal_sr_clean = librosa.load(input_wav_paths[3], sr=16000)
print(len(signal_clean),signal_clean,signal_sr_clean)

print(input_wav_paths[6])
#signal_snr_10 = sp.load_wav(input_wav_paths[6])
signal_snr_10, signal_sr_snr_10 = librosa.load(input_wav_paths[6], sr=16000)
print(len(signal_snr_10),signal_snr_10,signal_sr_snr_10)
# Out:
# /home/takkan/experiments/test_pesq_audio/demo_ssdrc_vs_imgan_hikari-003_057_quiet_imgan.wav
# 131147 [-0.00030746 -0.00034345 -0.00026417 ...  0.          0.
#   0.        ] 16000
# /home/takkan/experiments/test_pesq_audio/demo_ssdrc_vs_imgan_hikari-003_057_snr-10_imgan.wav
# 131147 [ 0.05400665 -0.04145639  0.01267751 ... -0.0679858  -0.04244706
#   0.        ] 16000

# %%
display(IPython.display.Audio(signal_clean, rate=signal_sr_clean))
display(IPython.display.Audio(signal_snr_10, rate=signal_sr_snr_10))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print(pesq(signal_sr_clean, signal_clean, signal_snr_10, 'wb'))
print(pesq(signal_sr_clean, signal_clean, signal_snr_10, 'nb'))
# Out:
# 1.0263944864273071
# 1.1143767833709717

# %% [markdown]
# # caluculate pesq score for ssdrc

# %%
print(input_wav_paths[4])
#signal_clean = sp.load_wav(input_wav_paths[4])
signal_clean, signal_sr_clean = librosa.load(input_wav_paths[4], sr=16000)
print(len(signal_clean),signal_clean,signal_sr_clean)

print(input_wav_paths[7])
#signal_snr_10 = sp.load_wav(input_wav_paths[7])
signal_snr_10, signal_sr_snr_10 = librosa.load(input_wav_paths[7], sr=16000)
print(len(signal_snr_10),signal_snr_10,signal_sr_snr_10)
# Out:
# /home/takkan/experiments/test_pesq_audio/demo_ssdrc_vs_imgan_hikari-003_057_quiet_ssdrc.wav
# 131209 [ 6.7671685e-08 -6.4851726e-08  5.6464842e-08 ...  0.0000000e+00
#   0.0000000e+00  0.0000000e+00] 16000
# /home/takkan/experiments/test_pesq_audio/demo_ssdrc_vs_imgan_hikari-003_057_snr-10_ssdrc.wav
# 131147 [ 0.0544385  -0.04105376  0.01293907 ... -0.0679858  -0.04244706
#   0.        ] 16000

# %%
display(IPython.display.Audio(signal_clean, rate=signal_sr_clean))
display(IPython.display.Audio(signal_snr_10, rate=signal_sr_snr_10))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print(pesq(signal_sr_clean, signal_clean, signal_snr_10, 'wb'))
print(pesq(signal_sr_clean, signal_clean, signal_snr_10, 'nb'))
# Out:
# 1.0183988809585571
# 1.0704275369644165
